# %% [markdown]
# # Lab | Error Handling
#
# Completed version based on the customer-order functions from the previous labs.

# %% [markdown]
# ## 1. Initialize inventory with error handling

# %%
def initialize_inventory(products):
    inventory = {}

    for product in products:
        while True:
            try:
                quantity = int(input(f"Enter the quantity of {product}s available: "))
                if quantity < 0:
                    raise ValueError("Quantity cannot be negative.")
                inventory[product] = quantity
                break
            except ValueError as error:
                print(f"Invalid input: {error} Please enter a non-negative whole number.")

    return inventory

# %% [markdown]
# ## 2. Calculate total price with error handling

# %%
def calculate_total_price(customer_orders):
    total_price = 0

    for product in customer_orders:
        while True:
            try:
                price = float(input(f"Enter the price of {product}: "))
                if price < 0:
                    raise ValueError("Price cannot be negative.")
                total_price += price
                break
            except ValueError as error:
                print(f"Invalid input: {error} Please enter a non-negative number.")

    return total_price

# %% [markdown]
# ## 3. Get customer orders with error handling

# %%
def get_customer_orders(inventory):
    while True:
        try:
            num_orders = int(input("Enter the number of customer orders: "))
            if num_orders < 0:
                raise ValueError("The number of orders cannot be negative.")
            break
        except ValueError as error:
            print(f"Invalid input: {error} Please enter a non-negative whole number.")

    customer_orders = []

    for _ in range(num_orders):
        while True:
            try:
                product = input("Enter the product name: ").strip().lower()
                if product not in inventory:
                    raise ValueError("This product is not in the inventory.")
                if inventory[product] <= 0:
                    raise ValueError("This product is out of stock.")
                if customer_orders.count(product) >= inventory[product]:
                    raise ValueError("There is not enough stock for another order of this product.")
                customer_orders.append(product)
                break
            except ValueError as error:
                print(f"Invalid product: {error} Available products: "
                      f"{[name for name, stock in inventory.items() if stock > 0]}")

    return customer_orders

# %% [markdown]
# ## Supporting functions and complete program

# %%
def update_inventory(inventory, customer_orders):
    for product in customer_orders:
        inventory[product] -= 1
    return {product: quantity for product, quantity in inventory.items() if quantity > 0}


def print_updated_inventory(inventory):
    print("Updated Inventory:")
    for product, quantity in inventory.items():
        print(f"{product}: {quantity}")


def main():
    products = ["t-shirt", "mug", "hat", "book", "keychain"]
    inventory = initialize_inventory(products)
    customer_orders = get_customer_orders(inventory)
    total_price = calculate_total_price(customer_orders)
    inventory = update_inventory(inventory, customer_orders)

    print(f"\nTotal products ordered: {len(customer_orders)}")
    print(f"Total price: {total_price:.2f}")
    print_updated_inventory(inventory)

# %% [markdown]
# ## 4. Manual test
#
# Run the cell below and deliberately try:
# - text and a negative number for inventory quantity;
# - text and a negative number for the number of orders;
# - an unknown product, an out-of-stock product and more orders than available stock;
# - text and a negative price.
#
# The program should display an error and ask again instead of stopping.

# %%
main()
